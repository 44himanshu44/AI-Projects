# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('/content/drive/My Drive/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# How many Survived??

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# **Analysing The Features**
#
# # Sex--> Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# # Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_735f5e6a_c62b_11e9_ba14_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with Sex and Pclass Together.

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_9a29b004_c62b_11e9_ba14_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# # Age--> Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# Observations:
# 1)The number of children increases with Pclass and the survival rate for passenegers below Age 10(i.e children) looks to be good irrespective of the Pclass.
#
# 2)Survival chances for Passenegers aged 20-50 from Pclass1 is high and is even better for Women.
#
# 3)For males, the survival chances decreases with an increase in age.

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_08a977a8_c62c_11e9_ba14_0242ac1c0002row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_08a977a8_c62c_11e9_ba14_0242ac1c0002row0_col13" class="data row0 col13" >125</td>
#                         <t

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# # Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# # Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row1_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row1_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row1_col4 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row2_col0 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row2_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row2_col3 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row2_col4 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row4_col1 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row5_col0 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row5_col1 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row5_col2 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row5_col3 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row5_col4 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row6_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row6_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row6_col2 {
#             background-color:  #e4f266;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row6_col3 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row6_col4 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row7_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row7_col1 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row7_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row7_col3 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row7_col4 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row8_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row8_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row8_col2 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row8_col3 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row8_col4 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row9_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002row9_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_c0ae32bc_c62c_11e9_ba14_0242ac1c0002level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_c0ae32bc_c62c_11e9_b

# %% [markdown]
# # SibSip-->Discrete Feature

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_0cfdee64_c62d_11e9_ba14_0242ac1c0002row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %% [markdown]
# # Fare--> Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
